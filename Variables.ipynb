# %% [markdown]
# <a href="https://www.viharatech.com"><img src="https://miro.medium.com/v2/resize:fit:828/format:webp/1*on2Bpj6A5gfd-CzaFOAZRA.jpeg"></a>
#
# ## Variables

# %%
## Rules to Define Variables
# 1) Variable name will not start with a number
# 2) No white spaces in variable names, use ‘_’ instead
# 3) Variable names are case sensitive
# 4) Can’t use below symbols in variable names,
#      !@#$%^&*(){}<>:”’?/|\~-+

# %%
_& = 1
print(_&)
# Out:
#   File "<ipython-input-37-2d1463c80648>", line 1
#     _& = 1
#        ^
# SyntaxError: invalid syntax

# %%
& = 'kamal'
print(&)
# Out:
#   File "<ipython-input-34-70db75df0ac8>", line 1
#     & = 'kamal'
#     ^
# SyntaxError: invalid syntax

# %%
13 = 'Data science '
print(13)
# Out:
#   File "<ipython-input-13-9b5b1eedf34b>", line 1
#     13 = 'Data science '
#                         ^
# SyntaxError: can't assign to literal

# %%
a = 'python'
print(a)
# Out:
# python

# %%
_9lives='pythont'
print(_9lives)
# Out:
# pythont

# %%
a = 32.2
print(a)
# Out:
# 32.2

# %%
a = 'kamal'
print(a)
# Out:
# kamal

# %%
_123 = 'Python'
print(_123)
# Out:
# Python

# %%
course123='datascience123'
print(course123)
# Out:
# datascience123

# %%
for i in range(10,0,-1):
  for j in range(i):
    print('*',end =" ")
    print()

# %%
#Python variables can only begin with a letter(A-Z/a-z) or an underscore(_)
9lives=9
# Out:
#   File "<ipython-input-26-7654601b3cea>", line 2
#     9lives=9
#          ^
# SyntaxError: invalid syntax

# %%
a = 1
print(a)
type(a)
# Out:
# 1
# int

# %%
b = 1.2
print(b)
type(b)
# Out:
# 1.2
# float

# %%
c = 'python'
print(c)
type(c)
# Out:
# python
# str

# %%
a = 1
b = 12.2
c = 'python'
print(a , b,c)
print(type(a) , type(b) , type(c))
# Out:
# 1 12.2 python
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# ## concept of case sensitive

# %%
# case sensitive means Capital letters and small letters
# Python is a case sensitive language

# %%
a = 1
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-50df8864ca78> in <module>
#       1 a = 1
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %%
a = 12
b = 12
print(a)
print(b)
# Out:
# 12
# 12

# %%
a = 12 # a is not in a private manner
b = a
print(b)
# Out:
# 12

# %%
name='Ayushi'
name
# Out:
# 'Ayushi'

# %%
 Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-da845b228b4c> in <module>
# ----> 1 Name
#
# NameError: name 'Name' is not defined

# %%
age=7
print(age)
# Out:
# 7

# %%
x = y = z = "Python"
print(x)
print(y)
print(z)
# Out:
# Python
# Python
# Python

# %%
a , b , c = 1 , 2 , 3

# %%
print(a , b , c)
# Out:
# 1 2 3

# %%
a , b , c = 'python', 1, 12.2
print(a , b , c)
# Out:
# python 1 12.2

# %%
age='Dinosaur'
print(age)
# Out:
# Dinosaur

# %%
 7=age
# Out:
#   File "<ipython-input-3-9b3bf22f1290>", line 1
#     7=age
#     ^
# SyntaxError: cannot assign to literal

# %%
# binary format ->  0 , 1 | True or flase | Yes or no

# %%
# True and False

# %%
False = choice
# Out:
#   File "<ipython-input-50-ec8e05622f95>", line 1
#     False = choice
#                    ^
# SyntaxError: can't assign to keyword

# %%
#Multiple assignment variable
age,city=21,'Indore'
print(age,city)
# Out:
# 21 Indore

# %%
age=fav=7        #you can assign the same value to multiple Python variables.
print(age,fav)
# Out:
# 7 7

# %%
a,b='red','blue'
a,b=b,a         #swapping variable
print(a,b)
# Out:
# blue red

# %%
a='red'

del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-93e365f002da> in <module>
#       2
#       3 del a
# ----> 4 a
#
# NameError: name 'a' is not defined

# %%
car="BMW"
Car="Mercedes"
CAR="Jaguar"
print(car)
print(Car)
print(CAR)
# Out:
# BMW
# Mercedes
# Jaguar
